# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import datasets
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('Issued_Construction_Permits.csv')
# Out:
# /home/scott/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (25,29,30,31,32,33,34,35,36,38,53,54,56,58,59,60,61,62,63,64,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ls
# Out:
# Construction_Permits_Issued_in_the_last_30_days.csv
# Issued_Construction_Permits.csv

# %%
dfa=df[df['TotalNewAddSQFT']>0]
iris=dfa[['OriginalZip','Longitude','Latitude','TotalNewAddSQFT', 'TotalJobValuation','NumberOfFloors']]
iris['TotalJobValuation']=iris['TotalJobValuation'].str.lstrip('$')
iris.fillna(value=0)
iris['TotalJobValuation']=iris['TotalJobValuation'].astype(float)
iris.dropna(inplace=True)
# Out:
# /home/scott/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/scott/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/scott/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#dfa['TotalJobValuation']=dfa['TotalJobValuation'].str.lstrip('$')
#dfa.fillna(value=0)
#dfa['TotalJobValuation']=dfa['TotalJobValuation'].astype(float)
#dfa.dropna(inplace=True)

# %%
dfa.groupby(['IssuedDate']).mean()
# Out:
#             CalendarYearIssued  FiscalYearIssued  TotalExistingBldgSQFT  \
# IssuedDate
# 1980/10/24              1980.0            1981.0                    NaN
# 1980/11/10              1980.0            1981.0                    NaN
# 1980/12/19              1980.0            1981.0               0.000000
# 1981/01/09              1981.0            1981.0                    NaN
# 1981/04/29              1981.0            1981.0                    NaN
# 1981/06/02              1981.0            1981.0                    NaN
# 1981/07/27              1981.0            1981.0                    NaN
# 1982/01/27              1982.0            1982.0                    NaN
# 1983/02/07              1983.0            1983.0                    NaN
# 1983/02/25              1983.0            1983.0                    NaN
# 1983/03/11              1983.0            1983.0                    NaN
# 1983/08/30              1983.0            1983.0                    NaN
# 1983/10/18              1983.0            1984.0                    NaN
# 1983/11/02              1983.0            1984.0                    NaN
# 1983/11/28              1983.0            1984.0                    NaN
# 1984/01/18              1984.0            1984.0                    NaN
# 1984/03/01              1984.0            1984.0                    NaN
# 1984/03/23              1984.0            1984.0                    NaN
# 1984/04/17              1984.0            1984.0                    NaN
# 1984/05/07              1984.0            1984.0                    NaN
# 1984/05/08              1984.0            1984.0                    NaN
# 1984/05/09              1984.0            1984.0                    NaN
# 1984/05/11              1984.0            1984.0                    NaN
# 1984/06/14              1984.0            1984.0                    NaN
# 1984/07/18              1984.0            1984.0                    NaN
# 1984/07/26              1984.0            1984.0                    NaN
# 1984/09/13              1984.0            1984.0                    NaN
# 1984/09/18              1984.0            1984.0               0.000000
# 1984/10/15              1984.0            1985.0                    NaN
# 1984/11/14              1984.0            1985.0                    NaN
# ...                        ...               ...                    ...
# 2017/12/19              2017.0            2018.0            2223.166667
# 2017/12/20              2017.0            2018.0            2571.000000
# 2017/12/21              2017.0            2018.0            2853.700000
# 2017/12/22              2017.0            2018.0            1583.000000
# 2017/12/23              2017.0            2018.0               0.000000
# 2017/12/24              2017.0            2018.0            1693.000000
# 2017/12/25              2017.0            2018.0                    NaN
# 2017/12/26              2017.0            2018.0            2089.500000
# 2017/12/27              2017.0            2018.0            2793.000000
# 2017/12/28              2017.0            2018.0            2591.571429
# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241714 entries, 47 to 1812268
# Data columns (total 66 columns):
# PermitType                    241714 non-null object
# PermitTypeDesc                241714 non-null object
# PermitNum                     241714 non-null object
# PermitClassMapped             241714 non-null object
# PermitClass                   241713 non-null object
# WorkClass                     241714 non-null object
# Condominium                   241714 non-null object
# ProjectName                   241646 non-null object
# Description                   241708 non-null object
# TCAD_ID                       241140 non-null object
# PropertyLegalDescription      206033 non-null object
# AppliedDate                   241714 non-null object
# IssuedDate                    241714 non-null object
# DayIssued                     241714 non-null object
# CalendarYearIssued            241714 non-null int64
# FiscalYearIssued              241714 non-null int64
# IssuedInLast30Days            241714 non-null object
# IssuanceMethod                241714 non-null object
# StatusCurrent                 241714 non-null object
# StatusDate                    241714 non-null object
# ExpiresDate                   241714 non-null object
# CompletedDate                 204648 non-null object
# TotalExistingBldgSQFT         21128 non-null float64
# RemodelRepairSQFT             688 non-null float64
# TotalNewAddSQFT               241714 non-null float64
# TotalValuationRemodel         7996 non-null object
# TotalJobValuation             91490 non-null object
# NumberOfFloors                232491 non-null float64
# HousingUnits                  228911 non-null float64
# BuildingValuation             12091 non-null object
# BuildingValuationRemodel      8175 non-null object
# ElectricalValuation           22059 non-null object
# ElectricalValuationRemodel    14673 non-null object
# MechanicalValuation           17972 non-null object
# MechanicalValuationRemodel    13293 non-null object
# PlumbingValuation             18879 non-null object
# PlumbingValuationRemodel      14423 non-null object
# MedGasValuation               0 non-null float64
# MedGasValuationRemodel        2585 non-null object
# OriginalAddress1              241708 non-null object
# OriginalCity                  241706 non-null object
# OriginalState                 241705 non-null object
# OriginalZip                   241705 non-null float64
# CouncilDistrict               227611 non-null float64
# Jurisdiction                  241709 non-null object
# Link                          241714 non-null object
# ProjectID                     241714 non-null int64
# MasterPermitNum               224884 non-null float64
# Latitude                      241694 non-null float64
# Longitude                     241694 non-null float64
# Location                      241694 non-null object
# ContractorTrade               240040 non-null object
# ContractorCompanyName         218185 non-null object
# ContractorFullName            178717 non-null object
# ContractorPhone               238969 non-null object
# ContractorAddress1            186220 non-null object
# ContractorAddress2            227860 non-null object
# ContractorCity                237250 non-null object
# ContractorZip                 234632 non-null object
# ApplicantFullName             18817 non-null object
# ApplicantOrganization         43059 non-null object
# ApplicantPhone                48136 non-null object
# ApplicantAddress1             32732 non-null object
# ApplicantAddress2             46696 non-null object
# ApplicantCity                 48243 non-null object
# ApplicantZip                  47067 non-null object
# dtypes: float64(11), int64(3), object(52)
# memory usage: 123.6+ MB

# %%
y=iris['TotalNewAddSQFT']
#y=y.iloc[1:]
x=iris.drop(labels='TotalNewAddSQFT',axis=1)
#x=x.iloc[0:-1]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=28)
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
rf.score(X_test,y_test)
# Out:
# 0.71872407380781889

# %%
dfa.drop(['IssuedInLast30Days','IssuanceMethod','Location','TCAD_ID','CalendarYearIssued','FiscalYearIssued','DayIssued','OriginalState','CouncilDistrict','Jurisdiction'],axis=1,inplace=True)

# %% [markdown]
# Build a random forest to predict total square footage on by month and by zip code basis for 2017 in Austin.

# %%
dfa['IssuedDate']=pd.to_datetime(dfa['IssuedDate'])
# Out:
# /home/scott/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfa.groupby(['IssuedDate','OriginalZip'])['TotalNewAddSQFT'].mean()
tbz=dfa.groupby(['OriginalZip'])['TotalNewAddSQFT'].sum()
tbz.nlargest(55)
# Out:
# OriginalZip
# 78701.0    106785051.0
# 78704.0     89346917.0
# 78758.0     75934839.0
# 78748.0     70908709.0
# 78744.0     60277889.0
# 78705.0     58428844.0
# 78717.0     55776922.0
# 78723.0     47604214.0
# 78703.0     45576134.0
# 78702.0     45063719.0
# 78754.0     44069518.0
# 78741.0     42466443.0
# 78735.0     39322965.0
# 78745.0     38277519.0
# 78753.0     36109552.0
# 78739.0     31989448.0
# 78746.0     30379981.0
# 78747.0     25113074.0
# 78727.0     23861601.0
# 78719.0     21481722.0
# 78660.0     20393027.0
# 78750.0     19403427.0
# 78757.0     18863244.0
# 78759.0     18644096.0
# 78724.0     18244990.0
# 78751.0     16217734.0
# 78731.0     15697374.0
# 78749.0     14884331.0
# 78726.0     14559911.0
# 78729.0     14448575.0
# 78617.0     14353823.0
# 78730.0     13884311.0
# 78732.0     13593914.0
# 78756.0     13194239.0
# 78738.0     12644241.0
# 78613.0     11024245.0
# 78728.0      8926910.0
# 78652.0      8890753.0
# 78736.0      8615565.0
# 78752.0      8130041.0
# 78734.0      7255100.0
# 78721.0      7126195.0
# 78733.0      6566191.0
# 78725.0      6271546.0
# 78722.0      3854372.0
# 78653.0      2967196.0
# 78737.0      1468444.0
# 78742.0       463731.0
# 78681.0       385017.0
# 78610.0        17012.0
# 78641.0         9697.0
# 78669.0         3500.0
# Name: TotalNewAddSQFT, dtype: float64

# %%
dfa.std()

# %%
df.shape
# Out:
# (1812269, 66)

# %%
plt.figure(figsize=(15,6))
zip_counts = dfa['OriginalZip'].value_counts()
ax1 = zip_counts.plot(kind='bar');
labels = []
for i, label in enumerate(zip_counts.index):
    labels.append('{} - ({})'.format(label, zip_counts[label]))
ax1.set_xticklabels(labels);
#Downtown - 78701 - had a tenth the *residential* development of 78702; huh.

# %%
plt.figure(figsize=(15,6))
floor_counts = dfa['NumberOfFloors'].value_counts()
ax1 = floor_counts.plot(kind='bar');
labels = []
for i, label in enumerate(floor_counts.index):
    labels.append('{} - ({})'.format(label, floor_counts[label]))
ax1.set_xticklabels(labels);

# %% [markdown]
# What the heck is a zero story project?! And two-story projects are half again as common as one-story.

# %%
plt.figure(figsize=(15,6))
desc_counts = dfa['PermitClass'].value_counts()
ax1 = desc_counts.plot(kind='bar');
labels = []
for i, label in enumerate(desc_counts.index):
    labels.append('{} - ({})'.format(label, desc_counts[label]))
ax1.set_xticklabels(labels);

# %%
plt.figure(figsize=(15,6))
jv_counts = dfa['TotalJobValuation'].value_counts()
ax1 = jv_counts.plot(kind='hist');
labels = []
for i, label in enumerate(jv_counts.index):
    labels.append('{} - ({})'.format(label, jv_counts[label]))
ax1.set_xticklabels(labels);
#Most projects are $150k-$250k

# %%
dfa['PermitClass'].unique()

# %%
dfa[dfa['Condominium']=='Yes'].count()

# %%
print(dfa[dfa['Condominium']=='Yes']['TotalNewAddSQFT'].sum())
print(dfa.sort_values('TotalNewAddSQFT', ascending=False))
howmany=dfa['ProjectName'].unique()
howmany.shape

# %%
print(dfa['OriginalZip'].unique())
dfa.sort_values('HousingUnits', ascending=False)

# %%
dfa['TotalNewAddSQFT'].sum()
#Over 1.3 billion square feet; seems low for over a hundred new people per day,
#but a lot of construction is likely unpermitted and many move into Austin metro
#- 4300 square miles and 2 million people, not Austin, 272 square miles and 800K people.

# %%
plt.figure(figsize=(22,11))
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.title('Austin new square footage')
plt.scatter(dfa['Longitude'],dfa['Latitude'], s=dfa['TotalNewAddSQFT']/1000,c='g')

# %%
''' This uses the Bokeh package so you will have to make sure it is loaded'''

from bokeh.models import (
   GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
 )
from bokeh.io import output_file, show, output_notebook
from bokeh.io import export_png



# Uncomment out this line to work within the jupyter notebook.
# If left commented out map should show in new window

output_notebook()

# %%
#creating the plot

## Set up the center point zoom and location for a given map
map_options = GMapOptions(lat=30.307182, lng=-97.76, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=Range1d(), y_range=Range1d(), map_options=map_options
)

plot.title.text = "Austin"

'''
This is someone else's API key so you should get your own at https://console.developers.google.com/apis/

You will need to make sure you have set up the permissions and services so you can use this.

I believe you need at least 
Google Maps JavaScript API
Google Static Maps API
Maybe more'''
plot.api_key = "AIzaSyBl6OOSxtxS7qmNgkm6EXdY6MSdVrHW8h4"



'''Here you will pass a list of the locations you want to show on the graph
The lats and longs are broken up into 2 lists'''
completed_lats = dfa['Latitude'].values
completed_longs = dfa['Longitude'].values
size=(dfa['TotalNewAddSQFT'].values**.25)/5


'''Setup for displaying the cordinates'''
completed_source = ColumnDataSource( data=dict(
    lat=completed_lats,
    lon=completed_longs,
    alpha=size))

'''The dots are put together and added to the plot'''
completed_dots = Circle(x="lon", y="lat", size='alpha', fill_color="red", fill_alpha=.5, line_color=None)
plot.add_glyph(completed_source, completed_dots)


'''This line setups up what functionality to allow (zoom etc)'''
plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

'''Show the map'''
show(plot)
export_png(plot, filename="plot.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8b2ddf948e75> in <module>()
#       2
#       3 ## Set up the center point zoom and location for a given map
# ----> 4 map_options = GMapOptions(lat=30.307182, lng=-97.76, map_type="roadmap", zoom=11)
#       5
#       6 plot = GMapPlot(
#
# NameError: name 'GMapOptions' is not defined

# %%
import scipy.stats as scs
import statsmodels.api as sm
pd.plotting.scatter_matrix(dfa, figsize=(15, 10))
plt.show()

# %%
dfa.describe().T
